# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/twitter_data.csv', encoding= 'ISO-8859-1')

# %%
df.shape
# Out:
# (1599999, 6)

# %%
#naming the columns
columns_names = ['target', 'id', 'date', 'flag', 'user', 'text']
df = pd.read_csv('data/twitter_data.csv', names = columns_names, encoding= 'ISO-8859-1')

# %%
df.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
df.shape
# Out:
# (1600000, 6)

# %%
df.isnull().sum()
# Out:
# target    0
# id        0
# date      0
# flag      0
# user      0
# text      0
# dtype: int64

# %%
df['target'].value_counts()
# Out:
# target
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %%
#convert 4 to 1
df.replace({'target':{4:1}}, inplace=True)
df['target'].value_counts()
# Out:
# target
# 0    800000
# 1    800000
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#          target          id                          date      flag  \
# 27651         0  1559316971  Sun Apr 19 10:49:26 PDT 2009  NO_QUERY
# 1076995       1  1967585691  Fri May 29 19:51:04 PDT 2009  NO_QUERY
# 1001030       1  1880059120  Thu May 21 23:58:29 PDT 2009  NO_QUERY
# 133671        0  1836062107  Mon May 18 07:17:49 PDT 2009  NO_QUERY
# 640392        0  2234974321  Fri Jun 19 00:08:53 PDT 2009  NO_QUERY
# 532205        0  2196659083  Tue Jun 16 12:45:50 PDT 2009  NO_QUERY
# 607792        0  2223088630  Thu Jun 18 07:50:09 PDT 2009  NO_QUERY
# 57933         0  1685783295  Sun May 03 02:03:26 PDT 2009  NO_QUERY
# 266686        0  1989039021  Mon Jun 01 00:08:51 PDT 2009  NO_QUERY
# 72924         0  1694374663  Mon May 04 02:20:10 PDT 2009  NO_QUERY
#
#                     user                                               text
# 27651       iamadarkstar  I couldn't fall asleep last night. Now I'm gon...
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]', ' ', content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)

    return stemmed_content

# %%
df['stemmed_content'] = df['text'].apply(stemming)

# %%
df.to_csv('data/filter_twitter_data.csv', index=False)
